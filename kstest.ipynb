# %%
import pandas

df = pandas.read_csv("experiment.csv")

df['experiment'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
print(df.experiment.describe())
# Out:
# count    50.000000
# mean      1.655183
# std       0.014282
# min       1.561255
# 25%       1.653989
# 50%       1.657234
# 75%       1.658043
# max       1.668947
# Name: experiment, dtype: float64

# %%
df1 = pandas.DataFrame(data={
    'df': df['experiment'],
})

df1.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from scipy import stats

d = df1['df']

print(stats.kstest(d, 'norm', (d.mean(), d.std()), N=len(d)))
# Out:
# KstestResult(statistic=0.3306226098558713, pvalue=2.2635160741143275e-05)
